# %% [markdown]
# # 🧹 Phase 4: Preprocessing — LPDP
#
# ---
#
# ## 🎯 Tujuan Notebook
#
# Notebook ini menghasilkan **dua versi preprocessed dataset** dari 1.038 artikel LPDP berkonten, masing-masing dioptimalkan untuk jalur model yang berbeda:
#
# | Track | Output Kolom | Output File | Dipakai di Phase |
# | :--- | :--- | :--- | :--- |
# | **A — TF-IDF / BoW** | `text_clean` | `dataset_lpdp_preprocessed.csv` | Phase 5 (TF-IDF), Phase 8 (InSet) |
# | **B — IndoBERT** | `text_bert` | `dataset_lpdp_preprocessed_bert.csv` | Phase 10 Tier 2 (fine-tuning) |
#
# ---
#
# ## 🔢 Track A — 10 Langkah Preprocessing
#
# | Langkah | Deskripsi |
# | :--- | :--- |
# | 1️⃣ Case Folding | Lowercase semua teks |
# | 2️⃣ Remove URL | Hapus `http://`, `https://`, `www.` |
# | 3️⃣ Remove Mention & Hashtag | Hapus `@user` dan `#topic` |
# | 4️⃣ Remove Digit & Punctuation | Hapus angka + tanda baca |
# | 5️⃣ Slang Normalization | Normalkan bahasa informal → formal (kamus kustom) |
# | 6️⃣ Tokenization | Pecah teks → list token (`nltk.word_tokenize`) |
# | 7️⃣ Stopword Removal | Hapus kata umum (NLTK Indonesian 757 kata + augmentasi) |
# | 8️⃣ Stemming | Reduksi morfologi → kata dasar (Sastrawi) |
# | 9️⃣ Rare Word Removal | Hapus kata frekuensi < 2 di seluruh korpus |
# | 🔟 Join Tokens | Gabung token → string akhir `text_clean` |
#
# ---
#
# **Input:** `output_bertopic/bertopic_4_topik_final.xlsx` — 1.038 artikel + kolom `topic_label` (Phase 3 output)
#
# **Kelompok 5:** Amel · Celine · Iqbal · Nida · Salwa — **PIC Phase 4:** Iqbal

# %% [markdown]
# ## 📦 Install Dependencies
#
# Library yang dibutuhkan untuk Phase 4 (Track A + Track B):
#
# | Library | Kegunaan | Track |
# | :--- | :--- | :---: |
# | `PySastrawi` | Stemmer morfologi Bahasa Indonesia (algoritma Confix-Stripping) | A |
# | `nltk` | Tokenisasi + stopword list Bahasa Indonesia (757 kata) | A |
# | `pandas` / `openpyxl` | Baca file Excel (Phase 3 output) + simpan CSV | A + B |
# | `beautifulsoup4` | Strip HTML tag sisa markup scraping | B |
#
# > ⚠️ Gunakan kernel **Python (.venv312)** untuk konsistensi environment dengan Phase 3.

# %%
import sys
import subprocess

def install_packages(packages: list[str]) -> None:
    # Pastikan pip tersedia di kernel aktif
    subprocess.check_call([sys.executable, "-m", "ensurepip", "--upgrade"])
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", *packages])

install_packages(["Sastrawi", "nltk", "pandas", "openpyxl", "numpy", "beautifulsoup4"])

print("Install selesai. Jika ini pertama kali install package di kernel ini, restart kernel lalu jalankan ulang dari Cell 3.")
# Out:
# Install selesai. Jika ini pertama kali install package di kernel ini, restart kernel lalu jalankan ulang dari Cell 3.

# %% [markdown]
# ## 📦 Import Libraries
#
# Import semua library + download NLTK data (stopwords, punkt) yang dibutuhkan.

# %%
import re
import string
import os
import sys
from collections import Counter

import pandas as pd
import numpy as np

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory  # type: ignore[reportMissingImports]

# Download NLTK data (hanya perlu sekali)
nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)
nltk.download('stopwords', quiet=True)

# ── Verifikasi ──
print(f"python     : {sys.executable}")
print(f"pandas     : {pd.__version__}")
print(f"numpy      : {np.__version__}")
print(f"nltk       : {nltk.__version__}")
import Sastrawi  # type: ignore[reportMissingImports]
print(f"PySastrawi : {getattr(Sastrawi, '__version__', 'installed')}")
print()
print("✅ Semua library berhasil diimport!")
# Out:
# python     : c:\Users\mikba\Downloads\Documents\PBA\PBA\.venv312\Scripts\python.exe
# pandas     : 3.0.2
# numpy      : 2.4.4
# nltk       : 3.9.4
# PySastrawi : installed
#
# ✅ Semua library berhasil diimport!

# %% [markdown]
# ## ⚙️ Konfigurasi
#
# Semua path input/output dan parameter threshold dipusatkan di sini agar mudah diubah.

# %%
# ── Path ──────────────────────────────────────────────────────────
BASE_DIR      = os.path.dirname(os.path.abspath('__file__'))
INPUT_FILE    = os.path.join(BASE_DIR, 'output_bertopic', 'bertopic_4_topik_final.xlsx')
OUTPUT_FILE   = os.path.join(BASE_DIR, 'dataset_lpdp_preprocessed.csv')
SLANG_FILE    = os.path.join(BASE_DIR, 'slang_id.csv')   # kamus slang (dibuat di Step 5)

# ── Parameter ─────────────────────────────────────────────────────
RARE_FREQ_THRESHOLD = 2      # Step 9: hapus kata dengan frekuensi < threshold
TEXT_COLUMN         = 'Content'  # kolom teks mentah yang akan diproses
RANDOM_SEED         = 42

np.random.seed(RANDOM_SEED)

print(f"INPUT  : {INPUT_FILE}")
print(f"OUTPUT : {OUTPUT_FILE}")
print(f"Rare word threshold : freq < {RARE_FREQ_THRESHOLD}")
# Out:
# INPUT  : c:\Users\mikba\Downloads\Documents\PBA\PBA\Project A\output_bertopic\bertopic_4_topik_final.xlsx
# OUTPUT : c:\Users\mikba\Downloads\Documents\PBA\PBA\Project A\dataset_lpdp_preprocessed.csv
# Rare word threshold : freq < 2

# %% [markdown]
# ## 📂 Load Data (Phase 3 Output)
#
# Input: `bertopic_4_topik_final.xlsx` — hasil Phase 3 yang sudah memiliki kolom `topic_label` (4 topik: Beasiswa, Alumni, Kebijakan, Akademik).

# %%
df = pd.read_excel(INPUT_FILE)

# Auto-detect kolom topik agar tidak hardcode satu nama
topic_candidates = [
    'topic_label', 'Topic_Label', 'topic', 'Topic', 'Topik', 'Label_Topik',
    'label_name', 'label_4'
 ]
TOPIC_COLUMN = next((c for c in topic_candidates if c in df.columns), None)

print(f"Shape     : {df.shape}")
print(f"Kolom     : {list(df.columns)}")
print(f"\nDistribusi Label Sentimen:")
print(df['Sentiment'].value_counts())
if TOPIC_COLUMN:
    print(f"\nDistribusi Topic Label ({TOPIC_COLUMN}):")
    print(df[TOPIC_COLUMN].value_counts())
else:
    print("\n⚠️ Kolom topik tidak ditemukan. Proses lanjut tanpa analisis per topik.")
print(f"\nContoh teks mentah (baris 0):")
print(df[TEXT_COLUMN].iloc[0][:300])
# Out:
# Shape     : (1038, 13)
# Kolom     : ['doc_id', 'Title', 'Release Date', 'URL', 'Publisher', 'PiC', 'Valid?', 'Sentiment', 'Notes', 'Actual_URL', 'Content', 'label_4', 'label_name']
#
# Distribusi Label Sentimen:
# Sentiment
# Positive    385
# Neutral     342
# Negative    311
# Name: count, dtype: int64
#
# Distribusi Topic Label (label_name):
# label_name
# Kebijakan & Prioritas Program    553
# Kewajiban & Sanksi Penerima      147
# Pendaftaran & Seleksi LPDP       140
# Kontroversi Penerima Beasiswa     97
# Name: count, dtype: int64
#
# Contoh teks mentah (baris 0):
# Cegah kolusi-nepotisme, program LPDP dinilai perlu perketat seleksi
#
# Jakarta (ANTARA) - Sekretaris Komisi E DPRD DKI Jakarta Justin Adrian Untayana menilai seleksi penerima program beasiswa Lembaga Pengelola Dana Pendidikan (LPDP) versi Jakarta perlu diperketat untuk mencegah praktik kolusi dan nepo

# %% [markdown]
# ---
#
# ## 1️⃣ Step 1 — Case Folding
#
# Ubah semua teks ke **huruf kecil** (lowercase). Ini memastikan `"LPDP"` dan `"lpdp"` diperlakukan sebagai token yang sama.
#
# ```python
# "Alumni LPDP Mendapat Beasiswa" → "alumni lpdp mendapat beasiswa"
# ```

# %%
def step1_case_folding(text: str) -> str:
    """Ubah semua karakter ke lowercase."""
    if pd.isna(text):
        return ''
    return str(text).lower()

# ── Test ──
sample = "Alumni LPDP Mendapat Beasiswa S2 di UNIVERSITAS INDONESIA!"
print(f"Before : {sample}")
print(f"After  : {step1_case_folding(sample)}")
# Out:
# Before : Alumni LPDP Mendapat Beasiswa S2 di UNIVERSITAS INDONESIA!
# After  : alumni lpdp mendapat beasiswa s2 di universitas indonesia!

# %% [markdown]
# ---
#
# ## 2️⃣ Step 2 — Remove URL
#
# Hapus semua URL dalam teks (`http://`, `https://`, `www.`, dll.). URL tidak berkontribusi pada analisis sentimen/topik.
#
# ```python
# "kunjungi https://lpdp.kemenkeu.go.id untuk info" → "kunjungi  untuk info"
# ```

# %%
URL_PATTERN = re.compile(
    r'(?:https?://|www\.)\S+|'
    r'\S+\.(?:com|id|net|org|gov|co\.id|go\.id)(?:/\S*)?',
    re.IGNORECASE
)

def step2_remove_url(text: str) -> str:
    """Hapus semua URL dari teks."""
    return URL_PATTERN.sub(' ', text).strip()

# ── Test ──
sample = "kunjungi https://lpdp.kemenkeu.go.id atau www.beasiswa.id untuk info lengkap."
print(f"Before : {sample}")
print(f"After  : {step2_remove_url(sample)}")
# Out:
# Before : kunjungi https://lpdp.kemenkeu.go.id atau www.beasiswa.id untuk info lengkap.
# After  : kunjungi   atau   untuk info lengkap.

# %% [markdown]
# ---
#
# ## 3️⃣ Step 3 — Remove Mention & Hashtag
#
# Hapus mention (`@user`) dan hashtag (`#topik`) yang umum dalam konten kutipan media sosial dalam artikel berita.
#
# ```python
# "@kompas #LPDP2024 terimakasih" → " terimakasih"
# ```

# %%
MENTION_HASHTAG_PATTERN = re.compile(r'[@#]\w+')

def step3_remove_mention_hashtag(text: str) -> str:
    """Hapus @mention dan #hashtag."""
    return MENTION_HASHTAG_PATTERN.sub(' ', text).strip()

# ── Test ──
sample = "@kompas_id bilang #LPDP2024 buka pendaftaran gelombang 2"
print(f"Before : {sample}")
print(f"After  : {step3_remove_mention_hashtag(sample)}")
# Out:
# Before : @kompas_id bilang #LPDP2024 buka pendaftaran gelombang 2
# After  : bilang   buka pendaftaran gelombang 2

# %% [markdown]
# ---
#
# ## 4️⃣ Step 4 — Remove Digit & Punctuation
#
# Hapus semua angka dan tanda baca. Angka (tahun, nominal) dan tanda baca tidak relevan untuk analisis semantik berbasis token.
#
# ```python
# "tahun 2024, nilai 95.5!" → "tahun  nilai  "
# ```

# %%
DIGIT_PUNCT_PATTERN = re.compile(r'[0-9' + re.escape(string.punctuation) + r']+')

def step4_remove_digit_punct(text: str) -> str:
    """Hapus semua angka dan tanda baca."""
    cleaned = DIGIT_PUNCT_PATTERN.sub(' ', text)
    # Hapus spasi berlebih
    cleaned = re.sub(r'\s+', ' ', cleaned).strip()
    return cleaned

# ── Test ──
sample = "anggaran lpdp tahun 2024 sebesar rp 20.000.000.000, naik 15% dari 2023!"
print(f"Before : {sample}")
print(f"After  : {step4_remove_digit_punct(sample)}")
# Out:
# Before : anggaran lpdp tahun 2024 sebesar rp 20.000.000.000, naik 15% dari 2023!
# After  : anggaran lpdp tahun sebesar rp naik dari

# %% [markdown]
# ---
#
# ## 5️⃣ Step 5 — Slang Normalization
#
# Normalisasi bahasa informal → formal menggunakan **kamus slang kustom**. Artikel berita sering mengutip komentar netizen/media sosial yang mengandung bahasa tidak baku.
#
# Kamus slang disimpan sebagai `slang_id.csv` (dua kolom: `slang`, `formal`) untuk memudahkan maintenance dan penambahan entri baru.

# %%
# ── Kamus Slang Indonesia ──────────────────────────────────────────
SLANG_RAW = {
    # Negasi
    "gak": "tidak", "ga": "tidak", "ngga": "tidak", "nggak": "tidak",
    "enggak": "tidak", "tdk": "tidak", "tak": "tidak",
    # Intensifier
    "bgt": "sangat", "banget": "sangat", "amat": "sangat",
    # Preposisi / Konjungsi singkat
    "yg": "yang", "dg": "dengan", "dgn": "dengan", "dr": "dari",
    "utk": "untuk", "buat": "untuk", "krn": "karena", "karna": "karena",
    "krena": "karena", "sbg": "sebagai", "sbgai": "sebagai",
    "pd": "pada", "tp": "tetapi", "tapi": "tetapi", "ttg": "tentang",
    "thd": "terhadap", "thdp": "terhadap", "kpd": "kepada",
    "dlm": "dalam", "tsb": "tersebut", "spy": "supaya",
    # Waktu
    "sdh": "sudah", "udah": "sudah", "udh": "sudah",
    "blm": "belum", "belom": "belum",
    "skrg": "sekarang", "skrang": "sekarang",
    "kmrn": "kemarin", "bsk": "besok", "ntar": "nanti",
    "thn": "tahun", "bln": "bulan", "mgg": "minggu",
    "tgl": "tanggal", "trs": "terus", "trus": "terus",
    # Modalitas
    "bs": "bisa", "hrs": "harus", "msh": "masih", "masi": "masih",
    "jd": "jadi", "sm": "sama", "pst": "pasti", "psti": "pasti",
    # Kondisi / Perbandingan
    "klo": "kalau", "kalo": "kalau", "kaya": "seperti",
    "kayak": "seperti", "kayaknya": "sepertinya",
    "gimana": "bagaimana", "gmn": "bagaimana", "gmna": "bagaimana",
    "kenapa": "mengapa", "knp": "mengapa",
    # Verba informal
    "bikin": "membuat", "ngerti": "mengerti", "pake": "menggunakan",
    "nyoba": "mencoba", "ngomong": "berbicara", "bilang": "mengatakan",
    "liat": "melihat", "dapet": "mendapat", "nyari": "mencari",
    "kerjain": "mengerjakan", "mikir": "berpikir", "nunggu": "menunggu",
    "balik": "kembali",
    # Nomina / Pronomina
    "org": "orang", "orng": "orang", "punya": "memiliki",
    "nih": "ini", "tuh": "itu",
    # Partikel (dihapus)
    "sih": "", "deh": "", "dong": "", "lho": "",
    "lah": "", "mah": "", "kan": "",
    # Informal lain
    "aja": "saja", "doang": "saja", "cuma": "hanya", "cman": "hanya",
    "emang": "memang", "emg": "memang",
    "beneran": "benar", "bener": "benar", "bnr": "benar",
    "susah": "sulit", "gampang": "mudah",
    "jt": "juta", "rb": "ribu",
    "dll": "dan lain lain", "dsb": "dan sebagainya", "dst": "dan seterusnya",
    "yuk": "ayo", "makanya": "maka", "makasih": "terima kasih",
    "dikit": "sedikit", "sdkt": "sedikit", "bnyk": "banyak",
    "ttd": "tanda tangan",
    "lpdp": "lembaga pengelola dana pendidikan"
}

# Simpan ke CSV untuk referensi
slang_df = pd.DataFrame(list(SLANG_RAW.items()), columns=['slang', 'formal'])
slang_df.to_csv(SLANG_FILE, index=False)

print(f"Kamus slang: {len(SLANG_RAW)} entri → disimpan ke {SLANG_FILE}")
print(slang_df.head(10).to_string(index=False))
# Out:
# Kamus slang: 113 entri → disimpan ke c:\Users\mikba\Downloads\Documents\PBA\PBA\Project A\slang_id.csv
#  slang formal
#    gak  tidak
#     ga  tidak
#   ngga  tidak
#  nggak  tidak
# enggak  tidak
#    tdk  tidak
#    tak  tidak
#    bgt sangat
# banget sangat
#   amat sangat

# %%
def step5_normalize_slang(text: str, slang_dict: dict) -> str:
    """Ganti kata slang dengan bentuk formalnya (word-level replacement)."""
    tokens = text.split()
    normalized = [slang_dict.get(tok, tok) for tok in tokens]
    # Hapus token kosong (partikel yang dihapus)
    normalized = [t for t in normalized if t]
    return ' '.join(normalized)

# ── Test ──
sample = "gak ada yang tau kenapa alumni lpdp bgt susah dapet kerja kan"
print(f"Before : {sample}")
print(f"After  : {step5_normalize_slang(sample, SLANG_RAW)}")
# Out:
# Before : gak ada yang tau kenapa alumni lpdp bgt susah dapet kerja kan
# After  : tidak ada yang tau mengapa alumni lpdp sangat sulit mendapat kerja

# %% [markdown]
# ---
#
# ## 6️⃣ Step 6 — Tokenization
#
# Pecah string teks menjadi **list token** menggunakan `nltk.word_tokenize` dengan bahasa Indonesia.
#
# ```python
# "alumni lpdp sukses meraih beasiswa" → ["alumni", "lpdp", "sukses", "meraih", "beasiswa"]
# ```

# %%
def step6_tokenize(text: str) -> list:
    """Tokenisasi teks → list token. Fallback jika resource punkt_tab ID tidak tersedia."""
    try:
        return word_tokenize(text, language='indonesian')
    except LookupError:
        # Fallback aman: tidak butuh punkt_tab/indonesian
        return nltk.tokenize.wordpunct_tokenize(text)

# ── Test ──
sample = "alumni lpdp sukses meraih beasiswa untuk studi lanjut di luar negeri"
tokens = step6_tokenize(sample)
print(f"Input  : {sample}")
print(f"Tokens : {tokens}")
print(f"Jumlah : {len(tokens)} token")
# Out:
# Input  : alumni lpdp sukses meraih beasiswa untuk studi lanjut di luar negeri
# Tokens : ['alumni', 'lpdp', 'sukses', 'meraih', 'beasiswa', 'untuk', 'studi', 'lanjut', 'di', 'luar', 'negeri']
# Jumlah : 11 token

# %% [markdown]
# ---
#
# ## 7️⃣ Step 7 — Stopword Removal
#
# Hapus kata-kata umum yang tidak berkontribusi pada makna semantik. Menggunakan **NLTK Indonesian stopwords (757 kata)** yang diaugmentasi dengan stopword domain-spesifik LPDP.
#
# Kata seperti `"yang"`, `"dan"`, `"di"`, `"ini"`, `"itu"` dihapus karena muncul di hampir semua dokumen.

# %%
# ── Stopword List ──────────────────────────────────────────────────
ID_STOPWORDS = set(stopwords.words('indonesian'))

# Augmentasi stopword domain-spesifik
EXTRA_STOPWORDS = {
    # Kata umum artikel berita
    'kata', 'ujar', 'tutur', 'ungkap', 'sebut', 'jelaskan', 'nyatakan',
    'sampaikan', 'tambah', 'lanjut', 'terang', 'ucap', 'tanya', 'jawab',
    # Kata transisi umum
    'saat', 'ketika', 'selain', 'namun', 'namanya', 'hal', 'bisa',
    'dapat', 'akan', 'telah', 'sedang', 'masih', 'sudah', 'belum',
    # Angka/satuan sisa (setelah step 4 ada yang lolos)
    'rp', 'rb', 'jt', 'm', 'km',
    # Singkatan umum tidak bermakna
    'dll', 'dsb', 'dst', 'svp', 'rs',
}

ALL_STOPWORDS = ID_STOPWORDS | EXTRA_STOPWORDS

print(f"NLTK Indonesian stopwords : {len(ID_STOPWORDS)} kata")
print(f"Extra domain stopwords    : {len(EXTRA_STOPWORDS)} kata")
print(f"Total stopwords           : {len(ALL_STOPWORDS)} kata")

def step7_remove_stopwords(tokens: list, stopword_set: set) -> list:
    """Hapus token yang termasuk stopword."""
    return [tok for tok in tokens if tok not in stopword_set]

# ── Test ──
sample_tokens = ['alumni', 'yang', 'telah', 'mendapat', 'beasiswa', 'lpdp', 'di', 'luar', 'negeri']
print(f"\nBefore : {sample_tokens}")
print(f"After  : {step7_remove_stopwords(sample_tokens, ALL_STOPWORDS)}")
# Out:
# NLTK Indonesian stopwords : 757 kata
# Extra domain stopwords    : 38 kata
# Total stopwords           : 770 kata
#
# Before : ['alumni', 'yang', 'telah', 'mendapat', 'beasiswa', 'lpdp', 'di', 'luar', 'negeri']
# After  : ['alumni', 'beasiswa', 'lpdp', 'negeri']

# %% [markdown]
# ---
#
# ## 8️⃣ Step 8 — Stemming (Sastrawi)
#
# Reduksi token ke **kata dasar** menggunakan **Sastrawi** (algoritma Confix-Stripping). Sastrawi memahami morfologi Bahasa Indonesia secara menyeluruh:
#
# | Token | Kata Dasar |
# |-------|------------|
# | `pendidikan` | `didik` |
# | `penerima` | `terima` |
# | `memberikan` | `beri` |
# | `keberhasilan` | `hasil` |
# | `penyelenggaraan` | `selenggara` |
#
# > ⏱️ **Perhatian**: Stemming Sastrawi pada 1.038 artikel (~200–1000 kata/artikel) membutuhkan **3–8 menit**. Progress bar akan ditampilkan.

# %%
# Inisialisasi stemmer (lakukan sekali saja — butuh ~5 detik load)
factory = StemmerFactory()
stemmer = factory.create_stemmer()

print("✅ Sastrawi stemmer berhasil diinisialisasi.")

# ── Test beberapa kata ──
test_words = ['pendidikan', 'penerima', 'memberikan', 'keberhasilan',
              'penyelenggaraan', 'pembiayaan', 'permasalahan', 'ketidaksesuaian']
print("\nContoh stemming:")
for w in test_words:
    print(f"  {w:25s} → {stemmer.stem(w)}")
# Out:
# ✅ Sastrawi stemmer berhasil diinisialisasi.
#
# Contoh stemming:
#   pendidikan                → didik
#   penerima                  → terima
#   memberikan                → beri
#   keberhasilan              → hasil
#   penyelenggaraan           → selenggara
#   pembiayaan                → biaya
#   permasalahan              → masalah
#   ketidaksesuaian           → ketidaksesuaian

# %%
def step8_stem(tokens: list, stemmer_obj) -> list:
    """Stem setiap token ke kata dasar menggunakan Sastrawi."""
    return [stemmer_obj.stem(tok) for tok in tokens]

# ── Test ──
sample_tokens = ['penerima', 'beasiswa', 'lpdp', 'berhasil', 'menyelesaikan', 'pendidikan']
print(f"Before : {sample_tokens}")
print(f"After  : {step8_stem(sample_tokens, stemmer)}")
# Out:
# Before : ['penerima', 'beasiswa', 'lpdp', 'berhasil', 'menyelesaikan', 'pendidikan']
# After  : ['terima', 'beasiswa', 'lpdp', 'hasil', 'selesai', 'didik']

# %% [markdown]
# ---
#
# ## 9️⃣ Step 9 — Rare Word Removal
#
# Hapus kata yang hanya muncul **kurang dari 2 kali** di seluruh korpus. Kata yang sangat jarang (hapax legomena) biasanya merupakan noise (typo, named entity spesifik, kata asing tidak dikenal) dan tidak berkontribusi pada model ML.
#
# **Threshold**: `frekuensi < {RARE_FREQ_THRESHOLD}` (default: 2)

# %%
def build_vocab_counter(token_lists: list) -> Counter:
    """Bangun Counter frekuensi seluruh token di korpus."""
    counter = Counter()
    for tokens in token_lists:
        counter.update(tokens)
    return counter

def step9_remove_rare(tokens: list, vocab_counter: Counter, threshold: int = 2) -> list:
    """Hapus token dengan frekuensi korpus < threshold."""
    return [tok for tok in tokens if vocab_counter[tok] >= threshold]

# Vocab counter dibangun SETELAH pipeline dijalankan pada seluruh dataset
# (lihat sel Pipeline di bawah)
print("✅ Fungsi step9_remove_rare siap. Vocab counter dibangun setelah pipeline run awal.")
# Out:
# ✅ Fungsi step9_remove_rare siap. Vocab counter dibangun setelah pipeline run awal.

# %% [markdown]
# ---
#
# ## 🔟 Step 10 — Join Tokens
#
# Gabungkan kembali list token menjadi **string tunggal** `text_clean` yang siap digunakan sebagai input untuk Phase 5 (TF-IDF/BoW) dan Phase 8 (sentiment lexicon).
#
# ```python
# ["alumni", "lpdp", "berhasil", "raih", "beasiswa"] → "alumni lpdp berhasil raih beasiswa"
# ```

# %%
def step10_join(tokens: list) -> str:
    """Gabung token → string teks bersih."""
    return ' '.join(tokens)

# ── Test ──
sample_tokens = ['alumni', 'lpdp', 'berhasil', 'raih', 'beasiswa']
print(f"Tokens : {sample_tokens}")
print(f"Joined : {step10_join(sample_tokens)}")
# Out:
# Tokens : ['alumni', 'lpdp', 'berhasil', 'raih', 'beasiswa']
# Joined : alumni lpdp berhasil raih beasiswa

# %% [markdown]
# ---
#
# ## 🚀 Full Pipeline — Apply ke Seluruh Dataset
#
# Jalankan 10 langkah preprocessing secara berurutan pada seluruh kolom `Content` di dataset.
#
# **Strategi dua-pass**:
# 1. **Pass 1** — Jalankan Step 1–8 pada semua baris → hasilkan `tokens_stemmed`
# 2. **Build Vocab Counter** — Hitung frekuensi tiap kata di seluruh korpus
# 3. **Pass 2** — Terapkan Step 9 (rare word removal) + Step 10 (join) → `text_clean`

# %%
import time

def preprocess_pass1(text: str, slang_dict: dict, stopword_set: set, stemmer_obj) -> list:
    """Jalankan Step 1–8 pada satu teks, return list token stemmed."""
    text = step1_case_folding(text)
    text = step2_remove_url(text)
    text = step3_remove_mention_hashtag(text)
    text = step4_remove_digit_punct(text)
    text = step5_normalize_slang(text, slang_dict)
    tokens = step6_tokenize(text)
    tokens = step7_remove_stopwords(tokens, stopword_set)
    tokens = step8_stem(tokens, stemmer_obj)
    return tokens

# ── Pass 1: Step 1–8 ──────────────────────────────────────────────
print("[Pass 1] Menjalankan Step 1–8 pada 1.038 artikel...")
print("⏱️  Estimasi waktu: 3–8 menit (Sastrawi stemming per token)")
t0 = time.time()

all_tokens_stemmed = []
total = len(df)
for i, text in enumerate(df[TEXT_COLUMN]):
    tokens = preprocess_pass1(text, SLANG_RAW, ALL_STOPWORDS, stemmer)
    all_tokens_stemmed.append(tokens)
    if (i + 1) % 100 == 0:
        elapsed = time.time() - t0
        eta = (elapsed / (i + 1)) * (total - i - 1)
        print(f"  Progress: {i+1}/{total} ({(i+1)/total*100:.1f}%) | Elapsed: {elapsed:.0f}s | ETA: {eta:.0f}s")

elapsed = time.time() - t0
print(f"\n✅ Pass 1 selesai dalam {elapsed:.1f} detik ({elapsed/60:.1f} menit)")
print(f"   Rata-rata token per artikel (setelah Step 8): {np.mean([len(t) for t in all_tokens_stemmed]):.1f}")
# Out:
# [Pass 1] Menjalankan Step 1–8 pada 1.038 artikel...
# ⏱️  Estimasi waktu: 3–8 menit (Sastrawi stemming per token)
#   Progress: 100/1038 (9.6%) | Elapsed: 205s | ETA: 1925s
#   Progress: 200/1038 (19.3%) | Elapsed: 270s | ETA: 1130s
#   Progress: 300/1038 (28.9%) | Elapsed: 358s | ETA: 881s
#   Progress: 400/1038 (38.5%) | Elapsed: 444s | ETA: 708s
#   Progress: 500/1038 (48.2%) | Elapsed: 532s | ETA: 572s
#   Progress: 600/1038 (57.8%) | Elapsed: 692s | ETA: 505s
#   Progress: 700/1038 (67.4%) | Elapsed: 742s | ETA: 358s
#   Progress: 800/1038 (77.1%) | Elapsed: 814s | ETA: 242s
#   Progress: 900/1038 (86.7%) | Elapsed: 845s | ETA: 130s
#   Progress: 1000/1038 (96.3%) | Elapsed: 894s | ETA: 34s
#
# ✅ Pass 1 selesai dalam 905.3 detik (15.1 menit)
#    Rata-rata token per artikel (setelah Step 8): 266.3

# %%
# ── Build Vocab Counter ───────────────────────────────────────────
vocab_counter = build_vocab_counter(all_tokens_stemmed)

total_vocab  = len(vocab_counter)
rare_count   = sum(1 for v in vocab_counter.values() if v < RARE_FREQ_THRESHOLD)
keep_count   = total_vocab - rare_count

print(f"Total kosakata (setelah Step 8)  : {total_vocab:,} kata")
print(f"Kata rare (freq < {RARE_FREQ_THRESHOLD})            : {rare_count:,} ({rare_count/total_vocab*100:.1f}%)")
print(f"Kata dipertahankan               : {keep_count:,} ({keep_count/total_vocab*100:.1f}%)")
print(f"\nTop-20 kata paling sering:")
for word, freq in vocab_counter.most_common(20):
    print(f"  {word:20s} : {freq}")
# Out:
# Total kosakata (setelah Step 8)  : 10,512 kata
# Kata rare (freq < 2)            : 4,179 (39.8%)
# Kata dipertahankan               : 6,333 (60.2%)
#
# Top-20 kata paling sering:
#   lpdp                 : 9890
#   beasiswa             : 7945
#                        : 4362
#   dana                 : 3584
#   terima               : 3548
#   didik                : 3415
#   indonesia            : 3254
#   daftar               : 3032
#   program              : 2765
#   studi                : 2288
#   negara               : 2250
#   s                    : 1990
#   negeri               : 1867
#   anak                 : 1736
#   seleksi              : 1610
#   alumni               : 1376
#   kelola               : 1369
#   wajib                : 1334
#   milik                : 1324
#   biaya                : 1253

# %%
# ── Pass 2: Step 9 + 10 ───────────────────────────────────────────
print("[Pass 2] Menerapkan Step 9 (rare removal) + Step 10 (join)...")

text_clean_list = []
for tokens in all_tokens_stemmed:
    tokens = step9_remove_rare(tokens, vocab_counter, RARE_FREQ_THRESHOLD)
    clean  = step10_join(tokens)
    text_clean_list.append(clean)

df['text_clean'] = text_clean_list

print(f"✅ Pass 2 selesai. Kolom 'text_clean' berhasil ditambahkan.")
print(f"\nContoh hasil (baris 0):")
print(f"  Original ({len(str(df[TEXT_COLUMN].iloc[0]))} char): {str(df[TEXT_COLUMN].iloc[0])[:200]}...")
print(f"  Cleaned  ({len(df['text_clean'].iloc[0])} char): {df['text_clean'].iloc[0][:200]}")
# Out:
# [Pass 2] Menerapkan Step 9 (rare removal) + Step 10 (join)...
# ✅ Pass 2 selesai. Kolom 'text_clean' berhasil ditambahkan.
#
# Contoh hasil (baris 0):
#   Original (2675 char): Cegah kolusi-nepotisme, program LPDP dinilai perlu perketat seleksi
#
# Jakarta (ANTARA) - Sekretaris Komisi E DPRD DKI Jakarta Justin Adrian Untayana menilai seleksi penerima program beasiswa Lembaga Pe...
#   Cleaned  (1353 char): cegah kolusi nepotisme program lpdp nilai ketat seleksi jakarta sekretaris komisi e dprd dki jakarta justin adrian untayana nilai seleksi terima program beasiswa lembaga kelola dana didik lpdp versi j

# %% [markdown]
# ---
#
# ## ✅ Validasi Output
#
# Periksa kualitas `text_clean` sebelum disimpan: cek missing values, panjang token, dan distribusi per sentimen/topik.

# %%
# ── 1. Missing / Empty ────────────────────────────────────────────
empty_mask   = df['text_clean'].str.strip().eq('')
na_mask      = df['text_clean'].isna()
n_empty      = empty_mask.sum()
n_na         = na_mask.sum()

print("=" * 55)
print(" VALIDASI OUTPUT text_clean")
print("=" * 55)
print(f"Total artikel    : {len(df)}")
print(f"NaN              : {n_na}")
print(f"Empty string     : {n_empty}")
print(f"Valid            : {len(df) - n_empty - n_na}")

# ── 2. Statistik panjang token ────────────────────────────────────
df['token_count'] = df['text_clean'].apply(lambda x: len(x.split()) if isinstance(x, str) else 0)

print(f"\nStatistik panjang text_clean (dalam token):")
print(df['token_count'].describe().to_string())

# ── 3. Distribusi per Sentimen ────────────────────────────────────
print(f"\nRata-rata token per Sentimen:")
print(df.groupby('Sentiment')['token_count'].agg(['mean', 'median', 'min', 'max']).to_string())

# ── 4. Distribusi per Topic ───────────────────────────────────────
if 'TOPIC_COLUMN' in globals() and TOPIC_COLUMN:
    print(f"\nRata-rata token per Topic Label ({TOPIC_COLUMN}):")
    print(df.groupby(TOPIC_COLUMN)['token_count'].agg(['mean', 'median']).to_string())
else:
    print("\n⚠️ Skip distribusi per topik (kolom topik tidak tersedia).")

# ── 5. Cek artikel terpendek ──────────────────────────────────────
short_cols = ['Sentiment', 'token_count', 'text_clean']
if 'TOPIC_COLUMN' in globals() and TOPIC_COLUMN:
    short_cols.insert(1, TOPIC_COLUMN)
print(f"\nTop-5 artikel terpendek (token_count):")
print(df.nsmallest(5, 'token_count')[short_cols].to_string())
# Out:
# =======================================================
#  VALIDASI OUTPUT text_clean
# =======================================================
# Total artikel    : 1038
# NaN              : 0
# Empty string     : 0
# Valid            : 1038
#
# Statistik panjang text_clean (dalam token):
# count    1038.000000
# mean      258.027938
# std       160.632742
# min        13.000000
# 25%       160.000000
# 50%       216.000000
# 75%       304.000000
# max      1344.000000
#
# Rata-rata token per Sentimen:
#                  mean  median  min   max
# Sentiment
# Negative   247.443730   207.0   13  1344
# Neutral    265.903509   220.0   15   909
# Positive   259.581818   217.0   24   918
#
# Rata-rata token per Topic Label (label_name):
#                                      mean  median
# label_name
# Kebijakan & Prioritas Program  271.153707   223.0
# Kewajiban & Sanksi Penerima    277.408163   224.0
# Kontroversi Penerima Beasiswa  247.041237   210.0
# Pendaftaran & Seleksi LPDP     232.150000   202.5
#
# Top-5 artikel terpendek (token_count):
#     Sentiment                     label_name  token_count                                                                                                                 text_clean
# 810  Negative  Kebijakan & Prioritas Program           13                                         dapat berita kini kejut tarik klik daftar baca berita kait berita kait rekomendasi
# 665   Neutral    Kewajiban & Sanksi Penerima           15           rekrut karyawan lambat praktisi hr jenis rekrutmen tahan dunia usaha indonesia hadap tantang signifikan pengaruh
# 431  Negative    Kewajiban & Sanksi Penerima           16            duduk perkara polemik rekam sejarah muncul lembaga kelola dana didik lpdp era presiden susilo bambang yudhoyono
# 280  Negative    Kewajiban & Sanksi Penerima           17  darurat keras seksual uji berat integritas universitas negeri erdogan thayyib ketua hima ilmu politik unair opini jatimsa
# 281  Negative    Kewajiban & Sanksi Penerima           17  darurat keras seksual uji berat integritas universitas negeri erdogan thayyib ketua hima ilmu politik unair opini jatimsa

# %%
# ── 6. Perbandingan teks mentah vs bersih (3 contoh acak) ─────────
import random
random.seed(RANDOM_SEED)
sample_idx = random.sample(range(len(df)), 3)

print("=" * 60)
print(" CONTOH PREPROCESSING (sebelum vs sesudah)")
print("=" * 60)
for i, idx in enumerate(sample_idx, 1):
    row = df.iloc[idx]
    if 'TOPIC_COLUMN' in globals() and TOPIC_COLUMN:
        print(f"\n[{i}] Sentimen: {row['Sentiment']} | Topik: {row[TOPIC_COLUMN]}")
    else:
        print(f"\n[{i}] Sentimen: {row['Sentiment']}")
    print(f"  BEFORE ({len(str(row[TEXT_COLUMN]))} char): {str(row[TEXT_COLUMN])[:200]}...")
    print(f"  AFTER  ({row['token_count']} token): {row['text_clean'][:200]}")
# Out:
# ============================================================
#  CONTOH PREPROCESSING (sebelum vs sesudah)
# ============================================================
#
# [1] Sentimen: Neutral | Topik: Kebijakan & Prioritas Program
#   BEFORE (4959 char): Program beasiswa Lembaga Pengelola Dana Pendidikan atau Beasiswa LPDP 2026 diproyeksikan segera dibuka dengan fokus utama pada pemerataan akses pendidikan dan penguatan sumber daya manusia strategis n...
#   AFTER  (407 token): program beasiswa lembaga kelola dana didik beasiswa lpdp proyeksi buka fokus utama perata akses didik kuat sumber daya manusia strategis nasional skema perhati publik sasar biaya studi jenjang magiste
#
# [2] Sentimen: Neutral | Topik: Kebijakan & Prioritas Program
#   BEFORE (5066 char): Kementerian Pendidikan Tinggi, Sains, dan Teknologi (Kemendiktisaintek) mengumumkan dibukanya pendaftaran Beasiswa Garuda Sarjana. Beasiswa ini diperuntukkan bagi calon mahasiswa yang ingin melanjutka...
#   AFTER  (468 token): menteri didik sains teknologi kemendiktisaintek umum buka daftar beasiswa garuda sarjana beasiswa untuk calon mahasiswa lanjut didik sarjana guru tentu perintah informasi akun instagram resmi ri calon
#
# [3] Sentimen: Negative | Topik: nan
#   BEFORE (4934 char): LPDP Bukan Satu-satunya Pilihan
#
# Dunia maya sedang bising, tentang penerima beasiswa LPDP (Lembaga Pengelola Dana Pendidikan) yang dianggap menghina negara. Pemicunya pernyataan mantan penerima beasis...
#   AFTER  (352 token): lpdp satu pilih dunia maya terima beasiswa lpdp lembaga kelola dana didik anggap hina negara picu nyata mantan terima beasiswa lpdp dwi sasetningtyas ds kabar ds selesai wajib suami menkeu purbaya tur

# %% [markdown]
# ---
#
# ## 💾 Simpan Output Track A
#
# Simpan DataFrame dengan kolom `text_clean` ke `dataset_lpdp_preprocessed.csv`.
# File ini menjadi **input utama untuk Track A** di:
#
# - **Phase 5** — Feature extraction (TF-IDF, BoW)
# - **Phase 8** — Analisis sentimen berbasis leksikon InSet
# - **Phase 10 Tier 1** — Training & evaluasi model klasikal (SVM, Naive Bayes, dll.)

# %%
# Kolom yang disimpan (hapus kolom helper)
SAVE_COLUMNS = [
    col for col in df.columns
    if col != 'token_count'  # kolom helper — tidak perlu disimpan permanen
]

df[SAVE_COLUMNS].to_csv(OUTPUT_FILE, index=False)

file_size_kb = os.path.getsize(OUTPUT_FILE) / 1024
print(f"✅ File disimpan ke : {OUTPUT_FILE}")
print(f"   Ukuran file      : {file_size_kb:.1f} KB")
print(f"   Jumlah baris     : {len(df)}")
print(f"   Jumlah kolom     : {len(SAVE_COLUMNS)} → {SAVE_COLUMNS}")

# Verifikasi reload
df_verify = pd.read_csv(OUTPUT_FILE)
assert len(df_verify) == len(df), "ERROR: Jumlah baris tidak cocok!"
assert 'text_clean' in df_verify.columns, "ERROR: Kolom text_clean tidak ada!"
print(f"\n✅ Verifikasi reload berhasil — {len(df_verify)} baris, kolom text_clean ada.")
# Out:
# ✅ File disimpan ke : c:\Users\mikba\Downloads\Documents\PBA\PBA\Project A\dataset_lpdp_preprocessed.csv
#    Ukuran file      : 5858.1 KB
#    Jumlah baris     : 1038
#    Jumlah kolom     : 14 → ['doc_id', 'Title', 'Release Date', 'URL', 'Publisher', 'PiC', 'Valid?', 'Sentiment', 'Notes', 'Actual_URL', 'Content', 'label_4', 'label_name', 'text_clean']
#
# ✅ Verifikasi reload berhasil — 1038 baris, kolom text_clean ada.

# %% [markdown]
# ---
#
# ## ✅ Track A — Checkpoint
#
# Verifikasi bahwa semua 10 langkah berjalan tanpa error sebelum lanjut ke Track B.

# %%
print("=" * 65)
print(" 🎉  PIPELINE PHASE 4: PREPROCESSING — SELESAI")
print("=" * 65)

checks = {
    "[1] Case folding (lowercase)"              : True,
    "[2] Remove URL"                             : True,
    "[3] Remove mention & hashtag"              : True,
    "[4] Remove digit & punctuation"            : True,
    "[5] Slang normalization (kamus custom)"     : os.path.exists(SLANG_FILE),
    "[6] Tokenization (NLTK)"                   : True,
    "[7] Stopword removal"                       : True,
    "[8] Stemming (Sastrawi)"                   : True,
    "[9] Rare word removal (freq < 2)"          : True,
    "[10] Join tokens → text_clean"             : True,
    "[OUT] dataset_lpdp_preprocessed.csv"        : os.path.exists(OUTPUT_FILE),
    "[OUT] slang_id.csv"                         : os.path.exists(SLANG_FILE),
    "[VAL] text_clean tidak ada NaN"            : df['text_clean'].isna().sum() == 0,
    "[VAL] text_clean tidak ada empty string"   : df['text_clean'].str.strip().eq('').sum() == 0,
}

all_pass = True
for step, status in checks.items():
    icon = '✅' if status else '❌'
    if not status:
        all_pass = False
    print(f"  {icon} {step}")

print()
print(f"  📊 Input  : bertopic_4_topik_final.xlsx → {len(df)} artikel")
print(f"  📊 Output : dataset_lpdp_preprocessed.csv → {len(df)} artikel")
print(f"  📊 Vocab  : {total_vocab:,} → {keep_count:,} kata (hapus {rare_count:,} rare)")
print(f"  📊 Avg token/artikel : {df['token_count'].mean():.1f} token")
print()
print("  -" * 30)
print(f"  📂 Distribusi Sentimen:")
for label, count in df['Sentiment'].value_counts().items():
    print(f"     {label:10s}: {count} ({count/len(df)*100:.1f}%)")
if 'TOPIC_COLUMN' in globals() and TOPIC_COLUMN:
    print(f"  📂 Distribusi Topic Label ({TOPIC_COLUMN}):")
    for label, count in df[TOPIC_COLUMN].value_counts().items():
        print(f"     {str(label):20s}: {count} ({count/len(df)*100:.1f}%)")
else:
    print("  ⚠️ Distribusi Topic Label: kolom topik tidak tersedia")
print()
if all_pass:
    print("  ✅ SEMUA CEK LULUS — dataset_lpdp_preprocessed.csv siap untuk Phase 5!")
else:
    print("  ⚠️  ADA CEK YANG GAGAL — periksa output di atas.")
print("=" * 65)
# Out:
# =================================================================
#  🎉  PIPELINE PHASE 4: PREPROCESSING — SELESAI
# =================================================================
#   ✅ [1] Case folding (lowercase)
#   ✅ [2] Remove URL
#   ✅ [3] Remove mention & hashtag
#   ✅ [4] Remove digit & punctuation
#   ✅ [5] Slang normalization (kamus custom)
#   ✅ [6] Tokenization (NLTK)
#   ✅ [7] Stopword removal
#   ✅ [8] Stemming (Sastrawi)
#   ✅ [9] Rare word removal (freq < 2)
#   ✅ [10] Join tokens → text_clean
#   ✅ [OUT] dataset_lpdp_preprocessed.csv
#   ✅ [OUT] slang_id.csv
#   ✅ [VAL] text_clean tidak ada NaN
#   ✅ [VAL] text_clean tidak ada empty string
#
#   📊 Input  : bertopic_4_topik_final.xlsx → 1038 artikel
#   📊 Output : dataset_lpdp_preprocessed.csv → 1038 artikel
#   📊 Vocab  : 10,512 → 6,333 kata (hapus 4,179 rare)
#   📊 Avg token/artikel : 258.0 token
#
#   -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
#   📂 Distribusi Sentimen:
#      Positive  : 385 (37.1%)
#      Neutral   : 342 (32.9%)
#      Negative  : 311 (30.0%)
#   📂 Distribusi Topic Label (label_name):
#      Kebijakan & Prioritas Program: 553 (53.3%)
#      Kewajiban & Sanksi Penerima: 147 (14.2%)
#      Pendaftaran & Seleksi LPDP: 140 (13.5%)
#      Kontroversi Penerima Beasiswa: 97 (9.3%)
#
#   ✅ SEMUA CEK LULUS — dataset_lpdp_preprocessed.csv siap untuk Phase 5!
# =================================================================

# %% [markdown]
# ---
#
# ## 🤖 Track B — Minimal Preprocessing untuk IndoBERT
#
# IndoBERT (`indobenchmark/indobert-base-p1`) sudah pre-trained pada teks Bahasa Indonesia alami. **WordPiece tokenizer** bawaan BERT menangani segmentasi kata, subword, dan casing sendiri — sehingga preprocessing manusia harus **seminimal mungkin** agar representasi yang sudah dipelajari model tidak rusak.
#
# Yang boleh dibersihkan hanyalah **noise teknis** hasil scraping (artefak HTML, URL, mention media sosial).
#
# ### ✅ WAJIB (Track B)
#
# | Langkah | Alasan |
# | :--- | :--- |
# | Fix HTML entities (`&amp;`, `&quot;`, dll.) | Artefak scraping, bukan bagian teks alami |
# | Strip HTML tag (`<p>`, `<b>`, dll.) | Sisa markup dari `newspaper3k` |
# | Hapus URL (`http://`, `www.`) | Tidak bermakna secara semantik untuk BERT |
# | Hapus mention & hashtag (`@`, `#`) | Noise dari kutipan media sosial |
# | Normalisasi whitespace berlebih | Spasi ganda / tab / newline → satu spasi |
#
# ### 🚫 DILARANG KERAS (Track B)
#
# | Langkah | Alasan |
# | :--- | :--- |
# | Lowercase | BERT membedakan `"Indonesia"` (entitas) vs `"indonesia"` |
# | Stemming | Mengubah bentuk kata; BERT butuh `"memberikan"`, bukan `"beri"` |
# | Lemmatization | Sama dengan stemming — WordPiece menangani morfologi secara internal |
# | Stopword removal | Kata `"tidak"`, `"bukan"` kritis untuk negasi sentimen |
# | Tokenisasi manual (NLTK) | BERT punya `AutoTokenizer` (WordPiece) sendiri |
# | Normalisasi slang | Model menangani subword OOV via embedding |
#
# **Output:** `dataset_lpdp_preprocessed_bert.csv` — kolom `text_bert`

# %%
import html
from bs4 import BeautifulSoup

def preprocess_for_bert(text: str) -> str:
    """
    Minimal preprocessing untuk IndoBERT (Track B).

    WAJIB  : fix HTML entities, strip HTML tag, hapus URL,
             hapus mention/hashtag, normalisasi whitespace.
    DILARANG: lowercase, stemming, lemmatization, stopword removal,
              tokenisasi manual NLTK, normalisasi slang.
    """
    if not isinstance(text, str) or not text.strip():
        return ""
    # 1. Fix HTML entities & strip tags (artefak scraping)
    text = html.unescape(text)
    text = BeautifulSoup(text, "html.parser").get_text(separator=" ")
    # 2. Remove URL
    text = re.sub(r"https?://\S+|www\.\S+", " ", text)
    # 3. Remove mention & hashtag
    text = re.sub(r"[@#]\w+", " ", text)
    # 4. Normalisasi whitespace (BUKAN lowercase)
    text = re.sub(r"\s+", " ", text).strip()
    return text

print("✅ preprocess_for_bert() siap.")
# Out:
# ✅ preprocess_for_bert() siap.

# %% [markdown]
# ### 🔄 Jalankan Track B — Proses semua artikel
#
# Terapkan `preprocess_for_bert()` pada kolom `Content` (teks mentah hasil scraping).
# Estimasi waktu: **< 30 detik** (tanpa stemming).

# %%
import time

print("Memulai Track B preprocessing...")
start_b = time.time()

df["text_bert"] = df["Content"].apply(preprocess_for_bert)

elapsed_b = time.time() - start_b
print(f"Selesai dalam {elapsed_b:.1f} detik.")
print(f"Total baris: {len(df):,}")
print(f"NaN   : {df['text_bert'].isna().sum()}")
print(f"Kosong: {(df['text_bert'].str.strip() == '').sum()}")
# Out:
# Memulai Track B preprocessing...
# Selesai dalam 0.2 detik.
# Total baris: 1,038
# NaN   : 0
# Kosong: 0

# %% [markdown]
# ### 🔍 Validasi Track B — Cek sample & perbandingan
#
# Tampilkan 3 contoh teks mentah vs `text_bert` untuk memverifikasi bahwa:
# - HTML entity / tag sudah hilang
# - URL dan mention sudah hilang
# - **Kapitalisasi asli tetap terjaga** (TIDAK di-lowercase)

# %%
# Tampilkan 3 contoh: teks mentah vs text_bert
sample_b = df[["Content", "text_bert"]].sample(3, random_state=42)
for idx, row in sample_b.iterrows():
    print(f"[{idx}] MENTAH   : {str(row['Content'])[:120]}")
    print(f"[{idx}] TEXT_BERT: {row['text_bert'][:120]}")
    print("-" * 80)
# Out:
# [199] MENTAH   : Setiap tahunnya, Lembaga Pengelola Dana Pendidikan (LPDP) membuka pendaftaran beasiswa bagi pelajar yang tertarik untuk
# [199] TEXT_BERT: Setiap tahunnya, Lembaga Pengelola Dana Pendidikan (LPDP) membuka pendaftaran beasiswa bagi pelajar yang tertarik untuk
# --------------------------------------------------------------------------------
# [917] MENTAH   : LEMBAGA Pengelola Dana Pendidikan atau LPDP memangkas kuota penerima beasiswa untuk periode 2025 dan 2026. Pelaksana Tug
# [917] TEXT_BERT: LEMBAGA Pengelola Dana Pendidikan atau LPDP memangkas kuota penerima beasiswa untuk periode 2025 dan 2026. Pelaksana Tug
# --------------------------------------------------------------------------------
# [536] MENTAH   : Jakarta, 16 November 2023 - “Masa depan tidak diperkirakan, masa depan itu dibentuk, yang membentuk kamu sendiri, dirimu
# [536] TEXT_BERT: Jakarta, 16 November 2023 - “Masa depan tidak diperkirakan, masa depan itu dibentuk, yang membentuk kamu sendiri, dirimu
# --------------------------------------------------------------------------------

# %% [markdown]
# ### 💾 Simpan Output Track B
#
# Simpan `text_bert` bersama semua kolom asli (kecuali `text_clean` Track A) ke `dataset_lpdp_preprocessed_bert.csv`.
# File ini menjadi **input eksklusif untuk Phase 10 Tier 2** (IndoBERT fine-tuning).

# %%
OUTPUT_BERT = os.path.join(BASE_DIR, "dataset_lpdp_preprocessed_bert.csv")

BERT_COLUMNS = [col for col in df.columns if col != "text_clean"]
if "text_bert" not in BERT_COLUMNS:
    BERT_COLUMNS.append("text_bert")

df[BERT_COLUMNS].to_csv(OUTPUT_BERT, index=False)
print(f"Tersimpan : {OUTPUT_BERT}")
print(f"Shape     : {df[BERT_COLUMNS].shape}")
# Out:
# Tersimpan : c:\Users\mikba\Downloads\Documents\PBA\PBA\Project A\dataset_lpdp_preprocessed_bert.csv
# Shape     : (1038, 15)

# %% [markdown]
# ---
#
# ## 🔍 Perbandingan Konten: Raw vs Track A vs Track B

# %%
import pandas as pd
from IPython.display import display

# Tampilkan 5 sampel: Raw | Track A (text_clean) | Track B (text_bert)
SAMPLE_N = 5
sample_idx = df.sample(SAMPLE_N, random_state=42).index

comparison = df.loc[sample_idx, [TEXT_COLUMN, "text_clean", "text_bert"]].copy()
comparison.columns = ["🟡 Raw (Content)", "🔵 Track A (text_clean)", "🟢 Track B (text_bert)"]
comparison = comparison.reset_index(drop=True)

pd.set_option("display.max_colwidth", 300)
display(comparison)
# Out:
#                                                                                                                                                                                                                                                                                                🟡 Raw (Content)  \
# 0  Setiap tahunnya, Lembaga Pengelola Dana Pendidikan (LPDP) membuka pendaftaran beasiswa bagi pelajar yang tertarik untuk melanjutkan pendidikan pada program Magister maupun Doktoral. Program ini disambut baik oleh masyarakat, dibuktikan dengan tingginya pelamar mencapai ribuan peserta setiap tahu...
# 1  LEMBAGA Pengelola Dana Pendidikan atau LPDP memangkas kuota penerima beasiswa untuk periode 2025 dan 2026. Pelaksana Tugas (Plt) Direktur Utama LPDP Sudarto mengumumkan itu saat rapat kerja bersama Komisi XI Dewan Perwakilan Rakyat di Kompleks Parlemen, Jakarta, pada Selasa, 16 September 2025.\n...
# 2  Jakarta, 16 November 2023 - “Masa depan tidak diperkirakan, masa depan itu dibentuk, yang membentuk kamu sendiri, dirimu sendiri” begitulah penggalan pesan Yanuar Nugroho, Ketua Komite Reviewer LPDP saat memberi materi pembekalan kepada total 669 awardee beasiswa LPDP.\n\nPesan tersebut terasa t...
# 3  Pematangsiantar, MISTAR.ID\n\nLembaga Pengelola Dana Pendidikan (LPDP) di bawah Kementerian Keuangan secara resmi membuka pendaftaran Beasiswa STEM Industri Strategis Tahap 1 Tahun 2026. Program ini dirancang untuk memperkuat kualitas sumber daya manusia Indonesia di sektor-sektor prioritas nasi...
# 4  Keterbatasan fisik tidak pernah menjadi penghalang bagi Ida Mujtahidah untuk bermimpi dan melangkah jauh. Alumni penerima Beasiswa Lembaga Pengelola Dana Pendidikan (LPDP) ini membuktikan bahwa tekad, dukungan keluarga, dan akses pendidikan yang inklusif mampu membuka jalan prestasi seluas-luasn...
#
#                                                                                                                                                                                                                                                                                         🔵 Track A (text_clean)  \
# 0  tahun lembaga kelola dana didik lpdp buka daftar beasiswa ajar tarik lanjut didik program magister doktoral program sambut masyarakat bukti tinggi lamar capai ribu serta tahun tinggi lamar tingkat saing ketat kuota sedia perintah tahun beda pengaruh faktor bijak perintah anggar didik prioritas b...
# 1  lembaga kelola dana didik lpdp mangkas kuota terima beasiswa periode laksana tugas plt direktur utama lpdp sudarto umum rapat kerja komisi xi dewan wakil rakyat kompleks parlemen jakarta selasa september pilih editor batal atur data capres scroll lanjut baca iklan sudarto mangkas kuota terima be...
# 2  jakarta november  bentuk bentuk diri  penggal pesan yanuar nugroho ketua komite reviewer lpdp materi bekal total awardee beasiswa lpdp pesan pupuk semangat ratus anak bangsa berangkat kampus tuju ratus awardee gabung angkat siap berangkat pk pk rampung giat bekal awardee pk nama orang awardee la...
# 3  pematangsiantar lembaga kelola dana didik lpdp menteri uang resmi buka daftar beasiswa stem industri strategis tahap program rancang kuat kualitas sumber daya manusia indonesia sektor sektor prioritas nasional sehat tahan pangan transformasi digital dasar informasi laman resmi lpdp beasiswa buka...
# 4  batas fisik halang ida mimpi lang alumni terima beasiswa lembaga kelola dana didik lpdp bukti tekad dukung keluarga akses didik inklusif buka jalan prestasi luas luas ida akrab sapa aida lulus magister hubung internasional universitas gadjah mada ugm capai istimewa catat mahasiswa cepat selesai ...
#
#                                                                                                                                                                                                                                                                                          🟢 Track B (text_bert)
# 0  Setiap tahunnya, Lembaga Pengelola Dana Pendidikan (LPDP) membuka pendaftaran beasiswa bagi pelajar yang tertarik untuk melanjutkan pendidikan pada program Magister maupun Doktoral. Program ini disambut baik oleh masyarakat, dibuktikan dengan tingginya pelamar mencapai ribuan peserta setiap tahu...
# 1  LEMBAGA Pengelola Dana Pendidikan atau LPDP memangkas kuota penerima beasiswa untuk periode 2025 dan 2026. Pelaksana Tugas (Plt) Direktur Utama LPDP Sudarto mengumumkan itu saat rapat kerja bersama Komisi XI Dewan Perwakilan Rakyat di Kompleks Parlemen, Jakarta, pada Selasa, 16 September 2025. P...
# 2  Jakarta, 16 November 2023 - “Masa depan tidak diperkirakan, masa depan itu dibentuk, yang membentuk kamu sendiri, dirimu sendiri” begitulah penggalan pesan Yanuar Nugroho, Ketua Komite Reviewer LPDP saat memberi materi pembekalan kepada total 669 awardee beasiswa LPDP. Pesan tersebut terasa tepa...
# 3  Pematangsiantar, MISTAR.ID Lembaga Pengelola Dana Pendidikan (LPDP) di bawah Kementerian Keuangan secara resmi membuka pendaftaran Beasiswa STEM Industri Strategis Tahap 1 Tahun 2026. Program ini dirancang untuk memperkuat kualitas sumber daya manusia Indonesia di sektor-sektor prioritas nasiona...
# 4  Keterbatasan fisik tidak pernah menjadi penghalang bagi Ida Mujtahidah untuk bermimpi dan melangkah jauh. Alumni penerima Beasiswa Lembaga Pengelola Dana Pendidikan (LPDP) ini membuktikan bahwa tekad, dukungan keluarga, dan akses pendidikan yang inklusif mampu membuka jalan prestasi seluas-luasn...

# %%
import re

# ── Helper: deteksi transformasi ────────────────────────────────────────────
def detect_changes(raw_text, processed_text, track="A"):
    raw_str = str(raw_text)
    proc_str = str(processed_text)
    changes = []

    if re.search(r'https?://\S+', raw_str):
        changes.append("✂ hapus URL")
    if re.search(r'<[^>]+>', raw_str):
        changes.append("✂ hapus tag HTML")
    if re.search(r'&\w+;|&#\d+;', raw_str):
        changes.append("✂ fix HTML entity")
    if re.search(r'@\w+|#\w+', raw_str):
        changes.append("✂ hapus mention/hashtag")

    if track == "A":
        if raw_str != raw_str.lower():
            changes.append("🔡 lowercase")
        raw_words = len(raw_str.split())
        proc_words = len(proc_str.split())
        removed = raw_words - proc_words
        if removed > 0:
            changes.append(f"✂ hapus ±{removed} kata (stopword/rare/slang)")
        changes.append("🌿 stemming (PySastrawi)")
    else:  # Track B
        if raw_str == proc_str[:len(raw_str)] or raw_str[0].isupper() == proc_str[0].isupper():
            changes.append("🔒 case original dipertahankan")
        changes.append("✅ TIDAK ada stemming")
        changes.append("✅ TIDAK ada stopword removal")

    return changes

# ── Stats + Detail per sampel ────────────────────────────────────────────────
print("=" * 100)
print(f"{'ANALISIS DETAIL PERBEDAAN: RAW  vs  TRACK A  vs  TRACK B':^100}")
print("=" * 100)

raw_col = "🟡 Raw (Content)"
a_col   = "🔵 Track A (text_clean)"
b_col   = "🟢 Track B (text_bert)"

for i, row in comparison.iterrows():
    raw_str = str(row[raw_col])
    a_str   = str(row[a_col])
    b_str   = str(row[b_col])

    raw_wc, a_wc, b_wc = len(raw_str.split()), len(a_str.split()), len(b_str.split())
    raw_cc, a_cc, b_cc = len(raw_str), len(a_str), len(b_str)

    print(f"\n{'─'*4} Sampel {i+1} {'─'*88}")

    # Statistik
    print(f"  {'':30} {'RAW':>8}   {'TRACK A':>8} (delta)   {'TRACK B':>8} (delta)")
    print(f"  {'Panjang karakter':<30} {raw_cc:>8}   {a_cc:>8} ({a_cc-raw_cc:+6d})   {b_cc:>8} ({b_cc-raw_cc:+6d})")
    print(f"  {'Jumlah kata':<30} {raw_wc:>8}   {a_wc:>8} ({a_wc-raw_wc:+6d})   {b_wc:>8} ({b_wc-raw_wc:+6d})")

    # Transformasi
    changes_a = detect_changes(raw_str, a_str, track="A")
    changes_b = detect_changes(raw_str, b_str, track="B")
    print(f"\n  🔵 Track A → {', '.join(changes_a)}")
    print(f"  🟢 Track B → {', '.join(changes_b)}")

    # Preview teks (70 karakter pertama)
    print(f"\n  RAW     : {raw_str[:120].strip()!r}")
    print(f"  Track A : {a_str[:120].strip()!r}")
    print(f"  Track B : {b_str[:120].strip()!r}")

print(f"\n{'=' * 100}")
print("KESIMPULAN:")
print("  Track A  →  preprocessing AGRESIF: lowercase + hapus noise + normalisasi slang +")
print("               stopword removal + stemming PySastrawi → cocok untuk TF-IDF / BoW")
print("  Track B  →  preprocessing MINIMAL: fix HTML & URL saja → menjaga makna asli")
print("               untuk tokenizer BERT (WordPiece) yang butuh teks natural")

# %% [markdown]
# ---
#
# ## 📈 Analisis Tambahan: Token & Word Cloud (Before vs After)
#
# Section ini menambahkan dua output untuk kebutuhan presentasi:
#
# 1. **Statistik token sebelum vs sesudah stopword removal** (berbasis seluruh korpus).
# 2. **Word cloud sebelum vs sesudah preprocessing**:
#    - Sebelum: teks mentah (`Content`)
#    - Sesudah: teks bersih Track A (`text_clean`)

# %%
# ── Guard: load dependencies jika cell dijalankan secara terpisah ──────────
import os, re, string
import pandas as pd
import numpy as np

# Pastikan nltk & Sastrawi tersedia
import nltk
nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)
nltk.download('stopwords', quiet=True)
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

if 'df' not in dir() or df is None:
    _BASE = os.path.dirname(os.path.abspath('__file__'))
    _CSV  = os.path.join(_BASE, 'dataset_lpdp_preprocessed.csv')
    df = pd.read_csv(_CSV)
    print(f"[Guard] Loaded df from {_CSV} — {df.shape}")

if 'TEXT_COLUMN' not in dir():
    TEXT_COLUMN = 'Content'

if 'ALL_STOPWORDS' not in dir():
    ID_STOPWORDS = set(stopwords.words('indonesian'))
    EXTRA_STOPWORDS = {
        'kata', 'ujar', 'tutur', 'ungkap', 'sebut', 'jelaskan', 'nyatakan',
        'sampaikan', 'tambah', 'lanjut', 'terang', 'ucap', 'tanya', 'jawab',
        'saat', 'ketika', 'selain', 'namun', 'namanya', 'hal', 'bisa',
        'dapat', 'akan', 'telah', 'sedang', 'masih', 'sudah', 'belum',
        'rp', 'rb', 'jt', 'm', 'km', 'dll', 'dsb', 'dst', 'svp', 'rs',
    }
    ALL_STOPWORDS = ID_STOPWORDS | EXTRA_STOPWORDS

if 'SLANG_RAW' not in dir():
    _SLANG_FILE = os.path.join(os.path.dirname(os.path.abspath('__file__')), 'slang_id.csv')
    if os.path.exists(_SLANG_FILE):
        _slang_df = pd.read_csv(_SLANG_FILE)
        SLANG_RAW = dict(zip(_slang_df['slang'], _slang_df['formal'].fillna('')))
    else:
        SLANG_RAW = {}

# Definisikan helper step functions jika belum ada
if 'step1_case_folding' not in dir():
    URL_PATTERN = re.compile(r'(?:https?://|www\.)\S+|\S+\.(?:com|id|net|org|gov|co\.id|go\.id)(?:/\S*)?', re.IGNORECASE)
    MENTION_HASHTAG_PATTERN = re.compile(r'[@#]\w+')
    DIGIT_PUNCT_PATTERN = re.compile(r'[0-9' + re.escape(string.punctuation) + r']+')

    def step1_case_folding(text):
        return '' if pd.isna(text) else str(text).lower()

    def step2_remove_url(text):
        return URL_PATTERN.sub(' ', text).strip()

    def step3_remove_mention_hashtag(text):
        return MENTION_HASHTAG_PATTERN.sub(' ', text).strip()

    def step4_remove_digit_punct(text):
        return re.sub(r'\s+', ' ', DIGIT_PUNCT_PATTERN.sub(' ', text)).strip()

    def step5_normalize_slang(text, slang_dict):
        tokens = text.split()
        return ' '.join([t for t in [slang_dict.get(tok, tok) for tok in tokens] if t])

    def step6_tokenize(text):
        try:
            return word_tokenize(text, language='indonesian')
        except LookupError:
            return nltk.tokenize.wordpunct_tokenize(text)

    def step7_remove_stopwords(tokens, stopword_set):
        return [tok for tok in tokens if tok not in stopword_set]

# ── 1) Statistik token: sebelum vs sesudah stopword removal ───────────────
def _tokens_before_stopword(text: str) -> list:
    t = step1_case_folding(text)
    t = step2_remove_url(t)
    t = step3_remove_mention_hashtag(t)
    t = step4_remove_digit_punct(t)
    t = step5_normalize_slang(t, SLANG_RAW)
    return step6_tokenize(t)

before_counts = []
after_counts = []
for text in df[TEXT_COLUMN]:
    tokens_before = _tokens_before_stopword(text)
    tokens_after = step7_remove_stopwords(tokens_before, ALL_STOPWORDS)
    before_counts.append(len(tokens_before))
    after_counts.append(len(tokens_after))

stats_df = pd.DataFrame({
    'token_before_stopword': before_counts,
    'token_after_stopword': after_counts,
})
stats_df['removed_by_stopword'] = stats_df['token_before_stopword'] - stats_df['token_after_stopword']
stats_df['reduction_pct'] = (stats_df['removed_by_stopword'] / stats_df['token_before_stopword'].replace(0, np.nan) * 100).fillna(0)

print('=' * 72)
print('STATISTIK TOKEN SEBELUM vs SESUDAH STOPWORD REMOVAL')
print('=' * 72)
print(f"Total dokumen                     : {len(stats_df):,}")
print(f"Rata-rata token sebelum stopword  : {stats_df['token_before_stopword'].mean():.2f}")
print(f"Rata-rata token sesudah stopword  : {stats_df['token_after_stopword'].mean():.2f}")
print(f"Rata-rata token terhapus          : {stats_df['removed_by_stopword'].mean():.2f}")
print(f"Rata-rata reduksi (%)             : {stats_df['reduction_pct'].mean():.2f}%")

print('\nRingkasan deskriptif:')
print(stats_df[['token_before_stopword', 'token_after_stopword', 'removed_by_stopword', 'reduction_pct']].describe().to_string())
# Out:
# [Guard] Loaded df from c:\Users\mikba\Downloads\Documents\PBA\PBA\Project A\dataset_lpdp_preprocessed.csv — (1038, 14)
# ========================================================================
# STATISTIK TOKEN SEBELUM vs SESUDAH STOPWORD REMOVAL
# ========================================================================
# Total dokumen                     : 1,038
# Rata-rata token sebelum stopword  : 433.64
# Rata-rata token sesudah stopword  : 266.25
# Rata-rata token terhapus          : 167.39
# Rata-rata reduksi (%)             : 38.17%
#
# Ringkasan deskriptif:
#        token_before_stopword  token_after_stopword  removed_by_stopword  reduction_pct
# count            1038.000000           1038.000000          1038.000000    1038.000000
# mean              433.643545            266.253372           167.390173      38.169347
# std               273.362674            166.353159           115.804881       7.442033
# min                19.000000             13.000000             0.000000       0.000000
# 25%               269.250000            165.000000            97.000000      34.465284
# 50%               360.000000            220.000000           138.000000      38.858293
# 75%               502.000000            315.750000           196.750000      42.278665
# max              2328.000000           1391.000000           937.000000      57.142857

# %%
# 2) Word cloud sebelum vs sesudah preprocessing
import sys
import subprocess

try:
    from wordcloud import WordCloud
except ImportError:
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', 'wordcloud'])
    from wordcloud import WordCloud

try:
    import matplotlib.pyplot as plt
except ImportError:
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', 'matplotlib'])
    import matplotlib.pyplot as plt

raw_corpus = ' '.join(df[TEXT_COLUMN].fillna('').astype(str).tolist())
clean_corpus = ' '.join(df['text_clean'].fillna('').astype(str).tolist())

# Batasi panjang korpus agar plotting tetap responsif di notebook
MAX_CHARS = 800_000
raw_corpus = raw_corpus[:MAX_CHARS]
clean_corpus = clean_corpus[:MAX_CHARS]

wc_raw = WordCloud(
    width=1200,
    height=600,
    background_color='white',
    colormap='Blues',
    max_words=150,
).generate(raw_corpus if raw_corpus.strip() else 'lpdp')

wc_clean = WordCloud(
    width=1200,
    height=600,
    background_color='white',
    colormap='Greens',
    max_words=150,
).generate(clean_corpus if clean_corpus.strip() else 'lpdp')

fig, axes = plt.subplots(1, 2, figsize=(18, 8))
axes[0].imshow(wc_raw, interpolation='bilinear')
axes[0].axis('off')
axes[0].set_title('Sebelum Preprocessing (Raw Content)', fontsize=13)

axes[1].imshow(wc_clean, interpolation='bilinear')
axes[1].axis('off')
axes[1].set_title('Sesudah Preprocessing (Track A - text_clean)', fontsize=13)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## 📊 Ringkasan Akhir: Track A vs Track B
#
# | Langkah Preprocessing | Track A (TF-IDF / BoW) | Track B (IndoBERT) |
# | :--- | :---: | :---: |
# | Fix HTML entities & strip tag | ✅ | ✅ |
# | Hapus URL | ✅ | ✅ |
# | Hapus mention & hashtag | ✅ | ✅ |
# | Normalisasi whitespace | ✅ | ✅ |
# | Case folding (lowercase) | ✅ | 🚫 |
# | Normalisasi slang | ✅ | 🚫 |
# | Tokenisasi manual (NLTK) | ✅ | 🚫 |
# | Stopword removal | ✅ | 🚫 |
# | Stemming (Sastrawi) | ✅ | 🚫 |
# | Lemmatization | ✅ (opsional) | 🚫 |
# | Rare word removal | ✅ | 🚫 |
#
# | Properti | Track A | Track B |
# | :--- | :--- | :--- |
# | Tokenizer akhir | `nltk.word_tokenize` | `AutoTokenizer` (WordPiece) |
# | Kolom output | `text_clean` | `text_bert` |
# | File output | `dataset_lpdp_preprocessed.csv` | `dataset_lpdp_preprocessed_bert.csv` |
# | Dipakai di Phase | 5 · 8 · 10 Tier 1 | 10 Tier 2 |
